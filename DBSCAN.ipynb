# %% [markdown]
# <a href="https://colab.research.google.com/github/ahasanulhossain07-del/machine_learning_book/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans

# %%
X,y=make_moons(n_samples=300,noise=0.06,random_state=42)
plt.scatter(X[:,0],X[:,1])
plt.title('Original Moons Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
plt.scatter(X_scaled[:,0],X_scaled[:,1])
plt.title('Scaled Moons Dataset')
plt.xlabel('Feature 1 (Standardized)')
plt.ylabel('Feature 2 (Standardized)')
plt.show()

# %%
dbscan=DBSCAN(eps=0.3,min_samples=3)

# %%
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3, min_samples=3)

# %%
label_dbscan=dbscan.labels_

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],hue=label_dbscan)
plt.title('DBSCAN Clustering Results')
plt.xlabel('Feature 1 (Scaled)')
plt.ylabel('Feature 2 (Scaled)')
plt.legend(title='Cluster')
plt.show()

# %%
#kmeans clustering
kmeans=KMeans(
    n_clusters=2,
    init='k-means++',
    max_iter=300,
    random_state=42
)
kmeans.fit(X_scaled)
label_kmeans = kmeans.labels_

sns.scatterplot(x = X_scaled[: ,0] , y =X_scaled[: ,1] , hue = label_kmeans ,palette = 'viridis' )
plt.title('K-Means Clustering Results')
plt.xlabel('Feature 1 (Scaled)')
plt.ylabel('Feature 2 (Scaled)')
plt.legend(title='Cluster')
plt.show()
